# %% [markdown]
# https://huggingface.co/smolagents

# %% [markdown]
# ### https://huggingface.co/smolagents

# %%
# !pip install smolagents[toolkit]
# Out:
# Collecting smolagents[toolkit]
#   Downloading smolagents-1.26.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub>=0.31.2 in /usr/local/lib/python3.12/dist-packages (from smolagents[toolkit]) (1.23.0)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from smolagents[toolkit]) (2.32.4)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.12/dist-packages (from smolagents[toolkit]) (13.9.4)
# Requirement already satisfied: jinja2>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from smolagents[toolkit]) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in /usr/local/lib/python3.12/dist-packages (from smolagents[toolkit]) (11.3.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from smolagents[toolkit]) (1.2.2)
# Collecting ddgs>=9.0.0 (from smolagents[toolkit])
#   Downloading ddgs-9.14.4-py3-none-any.whl.metadata (20 kB)
# Collecting markdownify>=0.14.1 (from smolagents[toolkit])
#   Downloading markdownify-1.2.3-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from ddgs>=9.0.0->smolagents[toolkit]) (8.4.2)
# Collecting primp>=1.2.3 (from ddgs>=9.0.0->smolagents[toolkit])
#   Downloading primp-1.3.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: lxml>=4.9.4 in /usr/local/lib/python3.12/dist-packages (from ddgs>=9.0.0->smolagents[toolkit]) (6.1.1)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (0.28.1)
# Collecting fake-useragent>=2.2.0 (from ddgs>=9.0.0->smolagents[toolkit])
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[toolkit]) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[toolkit]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[toolkit]) (1.5.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[toolkit]) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[toolkit]) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[toolkit]) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.31.2->smolagents[toolkit]) (4.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.4->smolagents[toolkit]) (3.0.3)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /usr/local/lib/python3.12/dist-packages (from markdownify>=0.14.1->smolagents[toolkit]) (4.13.5)
# Requirement already satisfied: six<2,>=1.15 in /usr/local/lib/python3.12/dist-packages (from markdownify>=0.14.1->smolagents[toolkit]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->smolagents[toolkit]) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->smolagents[toolkit]) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->smolagents[toolkit]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->smolagents[toolkit]) (2026.6.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.9.4->smolagents[toolkit]) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.9.4->smolagents[toolkit]) (2.20.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5,>=4.9->markdownify>=0.14.1->smolagents[toolkit]) (2.8.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (0.16.0)
# Requirement already satisfied: brotli in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (1.2.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (4.3.0)
# Collecting socksio==1.* (from httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit])
#   Downloading socksio-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents[toolkit]) (0.1.2)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs>=9.0.0->smolagents[toolkit]) (4.2.0)
# Downloading ddgs-9.14.4-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 5.0 MB/s eta 0:00:00
# Downloading markdownify-1.2.3-py3-none-any.whl (15 kB)
# Downloading smolagents-1.26.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 11.3 MB/s eta 0:00:00
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 11.2 MB/s eta 0:00:00
# Downloading socksio-1.0.0-py3-none-any.whl (12 kB)
# Downloading primp-1.3.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 84.6 MB/s eta 0:00:00
# Installing collected packages: socksio, primp, fake-useragent, markdownify, smolagents, ddgs
# Successfully installed ddgs-9.14.4 fake-useragent-2.2.0 markdownify-1.2.3 primp-1.3.1 smolagents-1.26.0 socksio-1.0.0

# %% [markdown]
# Successfully installed ddgs-9.14.4 fake-useragent-2.2.0 markdownify-1.2.3 primp-1.3.1 smolagents-1.26.0 socksio-1.0.0

# %%
from smolagents import CodeAgent, InferenceClientModel, DuckDuckGoSearchTool

# Initialize a model (using Hugging Face Inference API)
model = InferenceClientModel()  # Uses a default model

# Create an agent with no tools
agent = CodeAgent(
    tools=[DuckDuckGoSearchTool()],
    model=model,
)

# Run the agent with a task
result = agent.run("What is the current weather in Paris?")
print(result)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the current weather in Paris?                                                                           │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Error in generating model output:
# You must provide an api_key to work with auto API or log in with `hf auth login`.
# [Step 1: Duration 0.41 seconds]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/smolagents/agents.py in _step_stream(self, memory_step)
#    1676             else:
# -> 1677                 chat_message: ChatMessage = self.model.generate(
#    1678                     input_messages,
#
# /usr/local/lib/python3.12/dist-packages/smolagents/models.py in generate(self, messages, stop_sequences, response_format, tools_to_call_from, **kwargs)
#    1575         self._apply_rate_limit()
# -> 1576         response = self.retryer(self.client.chat_completion, **completion_kwargs)
#    1577         content = response.choices[0].message.content
#
# /usr/local/lib/python3.12/dist-packages/smolagents/utils.py in __call__(self, fn, *args, **kwargs)
#     556             try:
# --> 557                 result = fn(*args, **kwargs)
#     558
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/inference/_client.py in chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     922         }
# --> 923         request_parameters = provider_helper.prepare_request(
#     924             inputs=messages,
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/inference/_providers/_common.py in prepare_request(self, inputs, parameters, headers, model, api_key, extra_payload)
#      88         # api_key from user, or local token, or raise error
# ---> 89         api_key = self._prepare_api_key(api_key)
#      90
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/inference/_providers/_common.py in _prepare_api_key(self, api_key)
#     143         if api_key is None:
# --> 144             raise ValueError(
#     145                 f"You must provide an api_key to work with {self.provider} API or log in with `hf auth login`."
#
# ValueError: You must provide an api_key to work with auto API or log in with `hf auth login`.
#
# The above exception was the direct cause of the following exception:
#
# AgentGenerationError                      Traceback (most recent call last)
# /tmp/ipykernel_1379/3859541134.py in <cell line: 0>()
#      11
#      12 # Run the agent with a task
# ---> 13 result = agent.run("What is the current weather in Paris?")
#      14 print(result)
#
# /usr/local/lib/python3.12/dist-packages/smolagents/agents.py in run(self, task, stream, reset, images, additional_args, max_steps, return_full_result)
#     497
#     498         run_start_time = time.time()
# --> 499         steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     500
#     501         # Outputs are returned only at the end. We only look at the last step.
#
# /usr/local/lib/python3.12/dist-packages/smolagents/agents.py in _run_stream(self, task, max_steps, images)
#     594             except AgentGenerationError as e:
#     595                 # Agent generation errors are not caused by a Model error but an implementation error: so we should raise them and exit.
# --> 596                 raise e
#     597             except AgentError as e:
#     598                 # Other AgentError types are caused by the Model, so we should log them and iterate.
#
# /usr/local/lib/python3.12/dist-packages/smolagents/agents.py in _run_stream(self, task, max_steps, images)
#     576             self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
#     577             try:
# --> 578                 for output in self._step_stream(action_step):
#     579                     # Yield all
#     580                     yield output
#
# /usr/local/lib/python3.12/dist-packages/smolagents/agents.py in _step_stream(self, memory_step)
#    1698             memory_step.model_output = output_text
#    1699         except Exception as e:
# -> 1700             raise AgentGenerationError(f"Error in generating model output:\n{e}", self.logger) from e
#    1701
#    1702         ### Parse output ###
#
# AgentGenerationError: Error in generating model output:
# You must provide an api_key to work with auto API or log in with `hf auth login`.

# %%
# !hf auth login
# Out:
# Hint: A new version of huggingface_hub (1.26.1) is available! You are using version 1.23.0.
# To update, run: hf update
# ? How would you like to log in?  [Use arrows, Enter to confirm]
# > Log in with your browser
#   Paste an access token
# ? How would you like to log in? Log in with your browser
#
#     Open this URL in your browser:
#         https://hf.co/oauth/device
#
#     And enter the code: 6QTO-BAP2
#
#     Waiting for authorization.................
# Token is valid.
# The token `oauth-goodasdgood` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `oauth-goodasdgood`
# Note: This token will be refreshed automatically when it expires.

# %%
# !hf auth login
# Out:
# Hint: A new version of huggingface_hub (1.26.1) is available! You are using version 1.23.0.
# To update, run: hf update
# ? How would you like to log in?  [Use arrows, Enter to confirm]
# > Log in with your browser
#   Paste an access token
# ? How would you like to log in? Log in with your browser
#
#     Open this URL in your browser:
#         https://hf.co/oauth/device
#
#     And enter the code: 6QTO-BAP2
#
#     Waiting for authorization....

# %%
from smolagents import CodeAgent, InferenceClientModel, DuckDuckGoSearchTool

# Initialize a model (using Hugging Face Inference API)
model = InferenceClientModel()  # Uses a default model

# Create an agent with no tools
agent = CodeAgent(
    tools=[DuckDuckGoSearchTool()],
    model=model,
)

# Run the agent with a task
result = agent.run("What is the current weather in Paris?")
print(result)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the current weather in Paris?                                                                           │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Error in generating model output:
# (Request ID: Root=1-6a75104f-4a3cec4a017170203b851c47;92724af2-9854-4eac-9c23-3cc384d06ab7)
#
# Bad request:
# {'message': "The requested model 'Qwen/Qwen3-Next-80B-A3B-Thinking' is not supported by any provider you have
# enabled.", 'type': 'invalid_request_error', 'param': 'model', 'code': 'model_not_supported'}
# [Step 1: Duration 0.11 seconds]
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     794     try:
# --> 795         response.raise_for_status()
#     796     except httpx.HTTPStatusError as e:
#
# /usr/local/lib/python3.12/dist-packages/httpx/_models.py in raise_for_status(self)
#     828         message = message.format(self, error_type=error_type)
# --> 829         raise HTTPStatusError(message, request=request, response=self)
#     830
#
# HTTPStatusError: Client error '400 Bad Request' for url 'https://router.huggingface.co/v1/chat/completions'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/400
#
# The above exception was the direct cause of the following exception:
#
# BadRequestError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/smolagents/agents.py in _step_stream(self, memory_step)
#    1676             else:
# -> 1677                 chat_message: ChatMessage = self.model.generate(
#    1678                     input_messages,
#
# /usr/local/lib/python3.12/dist-packages/smolagents/models.py in generate(self, messages, stop_sequences, response_format, tools_to_call_from, **kwargs)
#    1575         self._apply_rate_limit()
# -> 1576         response = self.retryer(self.client.chat_completion, **completion_kwargs)
#    1577         content = response.choices[0].message.content
#
# /usr/local/lib/python3.12/dist-packages/smolagents/utils.py in __call__(self, fn, *args, **kwargs)
#     556             try:
# --> 557                 result = fn(*args, **kwargs)
#     558
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/inference/_client.py in chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     929         )
# --> 930         data = self._inner_post(request_parameters, stream=stream)
#     931
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/inference/_client.py in _inner_post(self, request_parameters, stream)
#     282             )
# --> 283             hf_raise_for_status(response)
#     284             if stream:
#
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     887             )
# --> 888             raise _format(BadRequestError, message, response) from e
#     889
#
# BadRequestError: (Request ID: Root=1-6a75104f-4a3cec4a017170203b851c47;92724af2-9854-4eac-9c23-3cc384d06ab7)
#
# Bad request:
# {'message': "The requested model 'Qwen/Qwen3-Next-80B-A3B-Thinking' is not supported by any provider you have enabled.", 'type': 'invalid_request_error', 'param': 'model', 'code': 'model_not_supported'}
#
# The above exception was the direct cause of the following exception:
#
# AgentGenerationError                      Traceback (most recent call last)
# /tmp/ipykernel_1379/3859541134.py in <cell line: 0>()
#      11
#      12 # Run the agent with a task
# ---> 13 result = agent.run("What is the current weather in Paris?")
#      14 print(result)
#
# /usr/local/lib/python3.12/dist-packages/smolagents/agents.py in run(self, task, stream, reset, images, additional_args, max_steps, return_full_result)
#     497
#     498         run_start_time = time.time()
# --> 499         steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     500
#     501         # Outputs are returned only at the end. We only look at the last step.
#
# /usr/local/lib/python3.12/dist-packages/smolagents/agents.py in _run_stream(self, task, max_steps, images)
#     594             except AgentGenerationError as e:
#     595                 # Agent generation errors are not caused by a Model error but an implementation error: so we should raise them and exit.
# --> 596                 raise e
#     597             except AgentError as e:
#     598                 # Other AgentError types are caused by the Model, so we should log them and iterate.
#
# /usr/local/lib/python3.12/dist-packages/smolagents/agents.py in _run_stream(self, task, max_steps, images)
#     576             self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
#     577             try:
# --> 578                 for output in self._step_stream(action_step):
#     579                     # Yield all
#     580                     yield output
#
# /usr/local/lib/python3.12/dist-packages/smolagents/agents.py in _step_stream(self, memory_step)
#    1698             memory_step.model_output = output_text
#    1699         except Exception as e:
# -> 1700             raise AgentGenerationError(f"Error in generating model output:\n{e}", self.logger) from e
#    1701
#    1702         ### Parse output ###
#
# AgentGenerationError: Error in generating model output:
# (Request ID: Root=1-6a75104f-4a3cec4a017170203b851c47;92724af2-9854-4eac-9c23-3cc384d06ab7)
#
# Bad request:
# {'message': "The requested model 'Qwen/Qwen3-Next-80B-A3B-Thinking' is not supported by any provider you have enabled.", 'type': 'invalid_request_error', 'param': 'model', 'code': 'model_not_supported'}

# %%
from smolagents import CodeAgent, TransformersModel, DuckDuckGoSearchTool

# تحميل نموذج محلي (مثلاً Qwen 2.5 7B)
# سيتم استهلاك حوالي 15 جيجا من الـ VRAM
model = TransformersModel(
    model_id="Qwen/Qwen2.5-1.5B-Instruct",
    device_map="auto" # سيقوم تلقائياً بتوزيع النموذج على الكرتين عندك
)

agent = CodeAgent(
    tools=[DuckDuckGoSearchTool()],
    model=model,
)

result = agent.run("What is the current weather in Paris?")
print(result)
# Out:
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors: reconstructing file:   0%|          |  0.00B / 3.09GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the current weather in Paris?                                                                           │
# │                                                                                                                 │
# ╰─ TransformersModel - Qwen/Qwen2.5-1.5B-Instruct ────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import openweathermap_api
#
#   # Fetching the weather forecast for Paris
#   forecast_response = openweathermap_api.weather_forecast(city='Paris')
#
#   # Extracting the current weather details
#   temperature = forecast_response['main']['temp'] - 273.15  # Convert Kelvin to Celsius
#   description = forecast_response['weather'][0]['description']
#
#   # Printing the current weather in Paris
#   print(f"The current temperature in Paris is approximately {round(temperature)} degrees Celsius, and the
#   description is {description}.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Warning to user: Code execution failed due to an unauthorized import - Consider passing said import under
# `additional_authorized_imports` when initializing your CodeAgent.
# Code execution failed at line 'import openweathermap_api' due to: InterpreterError: Import of openweathermap_api is
# not allowed. Authorized imports are: ['math', 'random', 'datetime', 'collections', 'statistics', 'unicodedata',
# 'itertools', 'queue', 'stat', 're', 'time']
# [Step 1: Duration 876.88 seconds| Input tokens: 2,083 | Output tokens: 168]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import requests
#
#   # Making a GET request to the OpenWeatherMap API to retrieve the weather forecast for Paris
#   response = requests.get('http://api.openweathermap.org/data/2.5/weather?q=Paris&appid=[YOUR_API_KEY]')
#
#   # Parsing the JSON response
#   forecast_data = response.json()
#
#   # Extracting the current weather details
#   temperature = forecast_data['main']['temp'] - 273.15  # Convert Kelvin to Celsius
#   description = forecast_data['weather'][0]['description']
#
#   # Printing the current weather in Paris
#   print(f"The current temperature in Paris is approximately {round(temperature)} degrees Celsius, and the
#   description is {description}.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Warning to user: Code execution failed due to an unauthorized import - Consider passing said import under
# `additional_authorized_imports` when initializing your CodeAgent.
# Code execution failed at line 'import requests' due to: InterpreterError: Import of requests is not allowed.
# Authorized imports are: ['math', 'random', 'datetime', 'collections', 'statistics', 'unicodedata', 'itertools',
# 'queue', 'stat', 're', 'time']
# [Step 2: Duration 1149.33 seconds| Input tokens: 4,602 | Output tokens: 455]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# [Step 3: Duration 635.52 seconds]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3088/1815132010.py in <cell line: 0>()
#      13 )
#      14
# ---> 15 result = agent.run("What is the current weather in Paris?")
#      16 print(result)
#
# /usr/local/lib/python3.12/dist-packages/smolagents/agents.py in run(self, task, stream, reset, images, additional_args, max_steps, return_full_result)
#     497
#     498         run_start_time = time.time()
# --> 499         steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     500
#     501         # Outputs are returned only at the end. We only look at the last step.
#
# /usr/local/lib/python3.12/dist-packages/smolagents/agents.py in _run_stream(self, task, max_steps, images)
#     576             self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
#     577             try:
# --> 578                 for output in self._step_stream(action_step):
#     579                     # Yield all
#     580                     yield output
#
# /usr/local/lib/python3.12/dist-packages/smolagents/agents.py in _step_stream(self, memory_step)
#    1675                 output_text = chat_message.content
#    1676             else:
# -> 1677                 chat_message: ChatMessage = self.model.generate(
#    1678                     input_messages,
#    1679                     stop_sequences=stop_sequences,
#
# /usr/local/lib/python3.12/dist-packages/smolagents/models.py in generate(self, messages, stop_sequences, response_format, tools_to_call_from, **kwargs)
#    1067         )
#    1068         count_prompt_tokens = generation_kwargs["inputs"].shape[1]  # type: ignore
# -> 1069         out = self.model.generate(
#    1070             **generation_kwargs,
#    1071         )
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     122         # pyrefly: ignore [bad-context-manager]
#     123         with ctx_factory():
# --> 124             return func(*args, **kwargs)
#     125
#     126     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, custom_generate, **kwargs)
#    2643
#    2644         # 9. Call generation mode
# -> 2645         result = decoding_method(
#    2646             self,
#    2647             input_ids,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2843
#    2844         prefill_consumed = False
# -> 2845         outputs = self._prefill(
#    2846             input_ids,
#    2847             generation_config,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _prefill(self, input_ids, generation_config, model_kwargs, is_first_iteration)
#    3894                 **model_kwargs,
#    3895             )
# -> 3896             return self(**model_inputs, return_dict=True)
#    3897
#    3898         # Chunked prefill (for very large contexts)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     909         if return_dict_passed is not None:
#     910             return_dict = return_dict_passed
# --> 911         output = func(self, *args, **kwargs)
#     912         if not return_dict and not isinstance(output, tuple):
#     913             output = output.to_tuple()
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen2/modeling_qwen2.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, logits_to_keep, **kwargs)
#     460         "Hey, are you conscious? Can you talk to me?\nI'm not conscious, but I can talk to you."
#     461         ```"""
# --> 462         outputs: BaseModelOutputWithPast = self.model(
#     463             input_ids=input_ids,
#     464             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#    1038                     output = func(self, *args, **kwargs)
#    1039             else:
# -> 1040                 output = func(self, *args, **kwargs)
#    1041         # Restore original config value
#    1042         finally:
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/output_capturing.py in wrapper(self, *args, **kwargs)
#     250             # Run the forward
#     251             try:
# --> 252                 outputs = func(self, *args, **kwargs)
#     253             # Reset the states
#     254             finally:
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen2/modeling_qwen2.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, **kwargs)
#     397
#     398         for i, decoder_layer in enumerate(self.layers[: self.config.num_hidden_layers]):
# --> 399             hidden_states = decoder_layer(
#     400                 hidden_states,
#     401                 attention_mask=causal_mask_mapping[self.config.layer_types[i]],
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_layers.py in __call__(self, *args, **kwargs)
#      91
#      92             return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93         return super().__call__(*args, **kwargs)
#      94
#      95
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen2/modeling_qwen2.py in forward(self, hidden_states, attention_mask, position_ids, past_key_values, use_cache, position_embeddings, **kwargs)
#     305         residual = hidden_states
#     306         hidden_states = self.post_attention_layernorm(hidden_states)
# --> 307         hidden_states = self.mlp(hidden_states)
#     308         hidden_states = residual + hidden_states
#     309         return hidden_states
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen2/modeling_qwen2.py in forward(self, x)
#      45
#      46     def forward(self, x):
# ---> 47         down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#      48         return down_proj
#      49
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     132         Runs the forward pass.
#     133         """
# --> 134         return F.linear(input, self.weight, self.bias)
#     135
#     136     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
from smolagents import CodeAgent, LiteLLMModel, DuckDuckGoSearchTool

# الاتصال بسيرفر llama.cpp المحلي الخاص بك
model = LiteLLMModel(
    model_id="openai/local", # اسم صوري
    api_base="http://localhost:8080/v1", # عنوان السيرفر الذي شغلت فيه llama-server
    api_key="none"
)

agent = CodeAgent(
    tools=[DuckDuckGoSearchTool()],
    model=model,
)

result = agent.run("What is the current weather in Paris?")
print(result)

# %%
from smolagents import CodeAgent, InferenceClientModel, DuckDuckGoSearchTool

# تحديد موديل متاح فعلياً على Hugging Face Inference API
model = InferenceClientModel(model_id="Qwen/Qwen2.5-Coder-32B-Instruct")

agent = CodeAgent(
    tools=[DuckDuckGoSearchTool()],
    model=model,
)

result = agent.run("What is the current weather in Paris?")
print(result)

# %%
#!pip install smolagents transformers accelerate torch

from smolagents import CodeAgent, TransformersModel, DuckDuckGoSearchTool

# تحميل نموذج صغير جداً يناسب المعالج ورامات كولاب
model = TransformersModel(
    model_id="Qwen/Qwen2.5-1.5B-Instruct",
    device_map="cpu" # إجبار التشغيل على المعالج
)

agent = CodeAgent(
    tools=[DuckDuckGoSearchTool()],
    model=model,
)

# تشغيل العميل
result = agent.run("What is the current weather in Paris?")
print(result)

# %% [markdown]
# /content# pip list
# Package                               Version
# ------------------------------------- ------------------
# absl-py                               1.4.0
# accelerate                            1.14.0
# access                                1.1.10.post3
# affine                                2.4.0
# aiofiles                              25.1.0
# aiohappyeyeballs                      2.7.1
# aiohttp                               3.14.1
# aiosignal                             1.4.0
# aiosqlite                             0.22.1
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.12.0
# altair                                5.5.0
# annotated-doc                         0.0.4
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.14.2
# anywidget                             0.9.21
# apsw                                  3.53.3.1
# apswutils                             0.1.2
# argon2-cffi                           25.1.0
# argon2-cffi-bindings                  25.1.0
# array_record                          0.8.3
# arrow                                 1.4.0
# arviz                                 0.22.0
# astropy                               7.2.2
# astropy-iers-data                     0.2026.7.13.0.54.2
# astunparse                            1.6.3
# atpublic                              5.1
# attrs                                 26.1.0
# audioread                             3.1.0
# Authlib                               1.7.2
# autograd                              1.9.1
# babel                                 2.18.0
# backcall                              0.2.0
# beartype                              0.22.9
# beautifulsoup4                        4.13.5
# betterproto                           2.0.0b6
# bigframes                             2.42.0
# bigquery-magics                       0.14.0
# bleach                                6.4.0
# blinker                               1.9.0
# blis                                  1.3.3
# blobfile                              3.2.0
# blosc2                                4.8.0
# bokeh                                 3.8.2
# Bottleneck                            1.4.2
# bqplot                                0.12.47
# branca                                0.8.2
# brotli                                1.2.0
# CacheControl                          0.14.4
# cachetools                            6.2.6
# catalogue                             2.0.10
# certifi                               2026.6.17
# cffi                                  2.1.0
# chardet                               5.2.0
# charset-normalizer                    3.4.9
# clarabel                              0.11.1
# click                                 8.4.2
# cligj                                 0.7.2
# cloudpathlib                          0.24.0
# cloudpickle                           3.1.2
# cmake                                 3.31.10
# cmdstanpy                             1.3.0
# colorcet                              3.2.1
# colorlover                            0.3.0
# community                             1.0.0b1
# confection                            1.3.3
# cons                                  0.4.7
# contourpy                             1.3.3
# cramjam                               2.11.0
# cryptography                          49.0.0
# cufflinks                             0.17.3
# curl_cffi                             0.15.0
# cvxopt                                1.3.2
# cvxpy                                 1.6.7
# cycler                                0.12.1
# cyipopt                               1.5.0
# cymem                                 2.0.13
# Cython                                3.0.12
# dask                                  2026.7.0
# dataproc-spark-connect                1.1.0
# datasets                              4.0.0
# db-dtypes                             1.7.1
# dbus-python                           1.2.18
# ddgs                                  9.14.4
# debugpy                               1.8.15
# decorator                             4.4.2
# defusedxml                            0.7.1
# deprecation                           2.1.0
# diffusers                             0.39.0
# dill                                  0.3.8
# distro                                1.9.0
# dlib                                  19.24.6
# dm-tree                               0.1.10
# docstring_parser                      0.18.0
# docutils                              0.21.2
# dopamine_rl                           4.1.2
# duckdb                                1.3.2
# earthengine-api                       1.7.35
# easydict                              1.13
# editdistance                          0.8.1
# eerepr                                0.1.2
# einops                                0.8.2
# en_core_web_sm                        3.8.0
# entrypoints                           0.4
# esda                                  2.9.0
# et_xmlfile                            2.0.0
# etils                                 1.14.0
# etuples                               0.3.10
# fake-useragent                        2.2.0
# Farama-Notifications                  0.0.6
# fastai                                2.8.7
# fastapi                               0.139.0
# fastcore                              2.0.5
# fastdownload                          0.0.7
# fastjsonschema                        2.21.2
# fastlite                              0.2.4
# fastprogress                          1.1.6
# fasttransform                         0.0.2
# filelock                              3.29.7
# firebase-admin                        6.9.0
# Flask                                 3.1.3
# flatbuffers                           25.12.19
# flax                                  0.11.2
# folium                                0.20.0
# fonttools                             4.63.0
# fqdn                                  1.5.1
# frozendict                            2.4.7
# frozenlist                            1.8.0
# fsspec                                2025.3.0
# future                                1.0.0
# gast                                  0.7.0
# gcsfs                                 2025.3.0
# GDAL                                  3.8.4
# gdown                                 5.2.2
# geemap                                0.38.3
# geocoder                              1.38.1
# geographiclib                         2.1
# geopandas                             1.1.4
# geopy                                 2.4.1
# giddy                                 2.3.6
# gin-config                            0.5.0
# gitdb                                 4.0.12
# GitPython                             3.1.51
# glob2                                 0.7
# google                                3.0.0
# google-adk                            2.4.0
# google-ai-generativelanguage          0.6.15
# google-api-core                       2.30.3
# google-api-python-client              2.198.0
# google-auth                           2.49.0
# google-auth-httplib2                  0.4.0
# google-auth-oauthlib                  1.4.0
# google-cloud-bigquery                 3.42.2
# google-cloud-bigquery-connection      1.22.0
# google-cloud-bigquery-storage         2.39.0
# google-cloud-core                     2.6.0
# google-cloud-dataproc                 5.28.0
# google-cloud-datastore                2.25.0
# google-cloud-firestore                2.27.0
# google-cloud-functions                1.24.0
# google-cloud-language                 2.21.0
# google-cloud-monitoring               2.31.0
# google-cloud-resource-manager         1.18.0
# google-cloud-spanner                  3.68.0
# google-cloud-storage                  3.13.0
# google-cloud-translate                3.27.0
# google-colab                          1.0.0
# google-crc32c                         1.8.0
# google-genai                          2.11.0
# google-generativeai                   0.8.6
# google-pasta                          0.2.0
# google-resumable-media                2.10.0
# googleapis-common-protos              1.75.0
# googledrivedownloader                 1.1.0
# gradio                                6.20.0
# gradio_client                         2.5.0
# grain                                 0.2.18
# graphviz                              0.21
# greenlet                              3.5.3
# groovy                                0.1.2
# grpc-google-iam-v1                    0.14.4
# grpc-interceptor                      0.15.4
# grpcio                                1.82.1
# grpcio-status                         1.71.2
# grpclib                               0.4.9
# gspread                               6.2.1
# gspread-dataframe                     4.0.0
# gym                                   0.25.2
# gym-notices                           0.1.0
# gymnasium                             1.3.0
# h11                                   0.16.0
# h2                                    4.3.0
# h5netcdf                              1.8.1
# h5py                                  3.16.0
# hdbscan                               0.8.44
# hf-gradio                             0.4.1
# hf-xet                                1.5.1
# highspy                               1.15.1
# holidays                              0.100
# holoviews                             1.23.1
# hpack                                 4.2.0
# html5lib                              1.1
# httpcore                              1.0.9
# httpcore2                             2.5.0
# httpimport                            1.4.1
# httplib2                              0.32.0
# httptools                             0.8.0
# httpx                                 0.28.1
# httpx2                                2.5.0
# huggingface_hub                       1.23.0
# humanize                              4.16.0
# hyperframe                            6.1.0
# hyperopt                              0.2.7
# ibis-framework                        9.5.0
# idna                                  3.18
# ImageIO                               2.37.3
# imageio-ffmpeg                        0.6.0
# imagesize                             2.0.0
# imbalanced-learn                      0.14.2
# immutabledict                         4.3.1
# importlib_metadata                    9.0.0
# importlib_resources                   7.1.0
# imutils                               0.5.4
# inequality                            1.1.2
# inflect                               7.5.0
# iniconfig                             2.3.0
# intel-cmplr-lib-ur                    2025.3.3
# intel-openmp                          2025.3.3
# ipyevents                             2.0.4
# ipyfilechooser                        0.6.0
# ipykernel                             6.17.1
# ipyleaflet                            0.20.0
# ipyparallel                           8.8.0
# ipython                               7.34.0
# ipython-genutils                      0.2.0
# ipython-sql                           0.5.0
# ipywidgets                            7.7.1
# isoduration                           20.11.0
# itsdangerous                          2.2.0
# jaraco.classes                        3.4.0
# jaraco.context                        6.1.2
# jaraco.functools                      4.5.0
# jax                                   0.7.2
# jaxlib                                0.7.2
# jeepney                               0.9.0
# jieba                                 0.42.1
# Jinja2                                3.1.6
# jiter                                 0.16.0
# joblib                                1.5.3
# joserfc                               1.7.3
# jsonpatch                             1.33
# jsonpickle                            4.1.2
# jsonpointer                           3.1.1
# jsonschema                            4.26.0
# jsonschema-specifications             2025.9.1
# jupyter_client                        7.4.9
# jupyter-console                       6.6.3
# jupyter_core                          5.9.1
# jupyter-events                        0.12.1
# jupyter_kernel_gateway                2.5.2
# jupyter-leaflet                       0.20.0
# jupyter_server                        2.20.0
# jupyter_server_terminals              0.5.4
# jupyterlab_pygments                   0.3.0
# jupyterlab_widgets                    3.0.16
# jupytext                              1.19.4
# kaggle                                2.0.2
# kagglehub                             1.0.2
# kagglesdk                             0.1.23
# keras                                 3.13.2
# keras-hub                             0.26.0
# keras-nlp                             0.26.0
# keyring                               25.7.0
# keyrings.google-artifactregistry-auth 1.1.2
# kiwisolver                            1.5.0
# langchain                             1.3.13
# langchain-core                        1.4.9
# langchain-protocol                    0.0.18
# langgraph                             1.2.9
# langgraph-checkpoint                  4.1.1
# langgraph-prebuilt                    1.1.0
# langgraph-sdk                         0.4.2
# langsmith                             0.10.2
# lark                                  1.3.1
# launchpadlib                          1.10.16
# lazr.restfulclient                    0.14.4
# lazr.uri                              1.0.6
# lazy-loader                           0.5
# libclang                              18.1.1
# libpysal                              4.14.1
# librosa                               0.11.0
# lightgbm                              4.6.0
# linkify-it-py                         2.1.0
# llvmlite                              0.43.0
# locket                                1.0.0
# logical-unification                   0.4.7
# lxml                                  6.1.1
# Mako                                  1.1.3
# mapclassify                           2.10.0
# Markdown                              3.10.2
# markdown-it-py                        4.2.0
# markdownify                           1.2.3
# MarkupSafe                            3.0.3
# matplotlib                            3.10.0
# matplotlib-inline                     0.2.2
# matplotlib-venn                       1.1.2
# mdit-py-plugins                       0.6.1
# mdurl                                 0.1.2
# mgwr                                  2.2.1
# miniKanren                            1.0.5
# missingno                             0.5.2
# mistune                               3.3.3
# mizani                                0.13.5
# mkl                                   2025.3.1
# ml_dtypes                             0.5.4
# mlxtend                               0.23.4
# mmh3                                  5.2.1
# momepy                                0.11.0
# more-itertools                        10.8.0
# moviepy                               1.0.3
# mpmath                                1.3.0
# msgpack                               1.2.1
# multidict                             6.7.1
# multipledispatch                      1.0.0
# multiprocess                          0.70.16
# multitasking                          0.0.13
# murmurhash                            1.0.15
# music21                               9.9.2
# namex                                 0.1.0
# narwhals                              2.24.0
# natsort                               8.4.0
# nbclassic                             1.3.3
# nbclient                              0.10.4
# nbconvert                             7.17.1
# nbformat                              5.10.4
# ndindex                               1.10.1
# nest-asyncio                          1.6.0
# networkx                              3.6.1
# nh3                                   0.3.6
# nibabel                               5.4.2
# nltk                                  3.9.1
# notebook                              6.5.7
# notebook_shim                         0.2.4
# numba                                 0.60.0
# numexpr                               2.14.1
# numpy                                 2.0.2
# nvidia-nccl-cu12                      2.30.7
# oauth2client                          4.1.3
# oauthlib                              3.3.1
# omegaconf                             2.3.1
# onemkl-license                        2025.3.1
# openai                                2.45.0
# opencv-contrib-python                 4.13.0.92
# opencv-python                         5.0.0.93
# opencv-python-headless                5.0.0.93
# openpyxl                              3.1.5
# opentelemetry-api                     1.42.1
# opentelemetry-resourcedetector-gcp    1.12.0a0
# opentelemetry-sdk                     1.42.1
# opentelemetry-semantic-conventions    0.63b1
# opt_einsum                            3.4.0
# optax                                 0.2.8
# optree                                0.19.1
# orbax-checkpoint                      0.12.1
# orjson                                3.11.9
# ormsgpack                             1.12.2
# osqp                                  1.1.3
# packaging                             26.2
# pandas                                2.2.2
# pandas-datareader                     0.11.1
# pandas-gbq                            0.30.0
# pandas-stubs                          2.2.2.240909
# pandocfilters                         1.5.1
# panel                                 1.9.3
# panel-material-ui                     0.14.0
# param                                 2.4.1
# parso                                 0.8.7
# parsy                                 2.2
# partd                                 1.4.2
# patsy                                 1.0.2
# peewee                                4.2.2
# peft                                  0.19.1
# pexpect                               4.9.0
# pickleshare                           0.7.5
# pillow                                11.3.0
# pip                                   24.1.2
# platformdirs                          4.10.0
# plotly                                5.24.1
# plotnine                              0.14.5
# pluggy                                1.6.0
# plum-dispatch                         2.9.0
# pointpats                             2.5.5
# polars                                1.35.2
# polars-runtime-32                     1.35.2
# pooch                                 1.9.0
# portpicker                            1.5.2
# preshed                               3.0.13
# prettytable                           3.18.0
# primp                                 1.3.1
# proglog                               0.1.12
# progressbar2                          4.5.0
# prometheus_client                     0.25.0
# promise                               2.3
# prompt_toolkit                        3.0.52
# propcache                             0.5.2
# prophet                               1.3.0
# proto-plus                            1.28.1
# protobuf                              5.29.6
# psutil                                5.9.5
# psycopg2                              2.9.12
# psygnal                               0.15.1
# ptyprocess                            0.7.0
# PuLP                                  3.3.2
# py-cpuinfo                            9.0.0
# py4j                                  0.10.9.9
# pyarrow                               18.1.0
# pyasn1                                0.6.4
# pyasn1_modules                        0.4.2
# pycairo                               1.29.0
# pycocotools                           2.0.11
# pycparser                             3.0
# pycryptodomex                         3.23.0
# pydantic                              2.13.4
# pydantic_core                         2.46.4
# pydata-google-auth                    1.9.1
# pydot                                 4.0.1
# pydotplus                             2.0.2
# PyDrive2                              1.21.1
# pydub                                 0.25.1
# pyerfa                                2.0.1.5
# pygame                                2.6.1
# pygit2                                1.19.3
# Pygments                              2.20.0
# PyGObject                             3.48.2
# pyiceberg                             0.11.1
# PyJWT                                 2.13.0
# pymc                                  5.28.5
# pynndescent                           0.6.0
# pyogrio                               0.13.0
# pyomo                                 6.10.1
# PyOpenGL                              3.1.10
# pyOpenSSL                             26.3.0
# pyparsing                             3.3.2
# pyperclip                             1.11.0
# pyproj                                3.7.2
# pyroaring                             1.1.0
# pysal                                 25.7
# pyshp                                 3.1.4
# PySocks                               1.7.1
# pyspark                               4.0.3
# pytensor                              2.38.3
# pytest                                8.4.2
# python-apt                            0.0.0
# python-box                            7.4.1
# python-dateutil                       2.9.0.post0
# python-dotenv                         1.2.2
# python-fasthtml                       0.14.6
# python-json-logger                    4.1.0
# python-louvain                        0.16
# python-multipart                      0.0.32
# python-slugify                        8.0.4
# python-snappy                         0.7.3
# python-utils                          4.0.0
# pytz                                  2025.2
# pyviz_comms                           3.0.6
# PyWavelets                            1.9.0
# PyYAML                                6.0.3
# pyzmq                                 26.2.1
# quantecon                             0.11.3
# rasterio                              1.5.0
# rasterstats                           0.21.0
# ratelim                               0.1.6
# referencing                           0.37.0
# regex                                 2025.11.3
# requests                              2.32.4
# requests-oauthlib                     2.0.0
# requests-toolbelt                     1.0.0
# requirements-parser                   0.9.0
# rfc3339-validator                     0.1.4
# rfc3986-validator                     0.1.1
# rfc3987-syntax                        1.1.0
# rich                                  13.9.4
# roman-numerals                        4.1.0
# roman-numerals-py                     4.1.0
# rpds-py                               2026.6.3
# rpy2                                  3.5.17
# rsa                                   4.9.1
# rtree                                 1.4.1
# safehttpx                             0.1.7
# safetensors                           0.8.0
# scikit-image                          0.25.2
# scikit-learn                          1.6.1
# scipy                                 1.16.3
# scooby                                0.11.2
# scs                                   3.2.11
# seaborn                               0.13.2
# SecretStorage                         3.5.0
# segregation                           2.5.4
# semantic-version                      2.10.0
# Send2Trash                            2.1.0
# sentence-transformers                 5.6.0
# sentencepiece                         0.2.2
# sentry-sdk                            2.65.0
# setuptools                            75.2.0
# shap                                  0.52.0
# shapely                               2.1.2
# shellingham                           1.5.4
# simple-parsing                        0.1.8
# simplejson                            4.1.1
# simsimd                               6.5.16
# six                                   1.17.0
# sklearn-compat                        0.1.6
# sklearn-pandas                        2.2.0
# slicer                                0.0.8
# smart_open                            8.0.0
# smmap                                 5.0.3
# smolagents                            1.26.0
# sniffio                               1.3.1
# snowballstemmer                       3.1.1
# socksio                               1.0.0
# soundfile                             0.14.0
# soupsieve                             2.8.4
# soxr                                  1.1.0
# spacy                                 3.8.14
# spacy-legacy                          3.0.12
# spacy-loggers                         1.0.5
# spaghetti                             1.7.6
# spanner-graph-notebook                1.1.10
# spglm                                 1.1.0
# Sphinx                                8.2.3
# sphinxcontrib-applehelp               2.0.0
# sphinxcontrib-devhelp                 2.0.0
# sphinxcontrib-htmlhelp                2.1.0
# sphinxcontrib-jsmath                  1.0.1
# sphinxcontrib-qthelp                  2.0.0
# sphinxcontrib-serializinghtml         2.0.0
# spint                                 1.1.0
# splot                                 1.1.7
# spopt                                 0.7.0
# spreg                                 1.9.0
# SQLAlchemy                            2.0.51
# sqlglot                               25.20.2
# sqlparse                              0.5.5
# srsly                                 2.5.3
# stanio                                0.5.1
# starlette                             1.3.1
# statsmodels                           0.14.6
# strictyaml                            1.7.3
# stringzilla                           4.6.2
# stumpy                                1.13.0
# sympy                                 1.14.0
# tables                                3.10.2
# tabulate                              0.9.0
# tbb                                   2022.3.1
# tcmlib                                1.5.0
# tenacity                              9.1.4
# tensorboard                           2.20.0
# tensorboard-data-server               0.7.2
# tensorflow                            2.20.0
# tensorflow-datasets                   4.9.10
# tensorflow-hub                        0.16.1
# tensorflow-metadata                   1.21.0
# tensorflow-probability                0.25.0
# tensorflow-text                       2.20.1
# tensorstore                           0.1.84
# termcolor                             3.3.0
# terminado                             0.18.1
# text-unidecode                        1.3
# textblob                              0.19.0
# tf_keras                              2.20.0
# tf-slim                               1.1.0
# thinc                                 8.3.13
# threadpoolctl                         3.6.0
# tifffile                              2026.4.11
# tiktoken                              0.13.0
# timm                                  1.0.28
# tinycss2                              1.5.1
# tobler                                0.14.0
# tokenizers                            0.22.2
# toml                                  0.10.2
# tomlkit                               0.14.0
# toolz                                 0.12.1
# torch                                 2.11.0+cpu
# torchao                               0.10.0
# torchaudio                            2.11.0+cpu
# torchcodec                            0.11.0+cpu
# torchdata                             0.11.0
# torchsummary                          1.5.1
# torchtune                             0.6.1
# torchvision                           0.26.0+cpu
# tornado                               6.5.7
# tqdm                                  4.67.3
# traitlets                             5.7.1
# traittypes                            0.2.3
# transformers                          5.13.1
# treescope                             0.1.10
# truststore                            0.10.4
# tsfresh                               0.21.2
# tweepy                                4.17.0
# typeguard                             4.5.2
# typer                                 0.26.8
# types-pytz                            2026.2.0.20260518
# types-setuptools                      82.0.0.20260518
# typing_extensions                     4.16.0
# typing-inspection                     0.4.2
# tzdata                                2026.3
# tzlocal                               5.4.4
# uc-micro-py                           2.0.0
# umap-learn                            0.5.12
# umf                                   1.0.3
# uri-template                          1.3.0
# uritemplate                           4.2.0
# urllib3                               2.5.0
# uuid_utils                            0.17.0
# uvicorn                               0.51.0
# uvloop                                0.22.1
# vega-datasets                         0.9.0
# wadllib                               1.3.6
# wandb                                 0.28.0
# wasabi                                1.1.3
# watchdog                              6.0.0
# watchfiles                            1.2.0
# wcwidth                               0.8.2
# weasel                                1.0.0
# webcolors                             25.10.0
# webencodings                          0.5.1
# websocket-client                      1.9.0
# websockets                            15.0.1
# Werkzeug                              3.1.8
# wheel                                 0.47.0
# widgetsnbextension                    3.6.10
# wordcloud                             1.9.6
# wrapt                                 2.2.2
# xarray                                2025.12.0
# xarray-einstats                       0.10.0
# xgboost                               3.3.0
# xlrd                                  2.0.2
# xxhash                                3.8.1
# xyzservices                           2026.3.0
# yarl                                  1.24.2
# ydf                                   0.15.0
# ydf_tf                                2.20.0
# yellowbrick                           1.5
# yfinance                              0.2.66
# zipp                                  4.1.0
# zstandard                             0.25.0
# /content# ^C
# /content#

# %%
/content# pip list
Package                               Version
------------------------------------- ------------------
absl-py                               1.4.0
accelerate                            1.14.0
access                                1.1.10.post3
affine                                2.4.0
aiofiles                              25.1.0
aiohappyeyeballs                      2.7.1
aiohttp                               3.14.1
aiosignal                             1.4.0
aiosqlite                             0.22.1
alabaster                             1.0.0
albucore                              0.0.24
albumentations                        2.0.8
ale-py                                0.12.0
altair                                5.5.0
annotated-doc                         0.0.4
annotated-types                       0.7.0
antlr4-python3-runtime                4.9.3
anyio                                 4.14.2
anywidget                             0.9.21
apsw                                  3.53.3.1
apswutils                             0.1.2
argon2-cffi                           25.1.0
argon2-cffi-bindings                  25.1.0
array_record                          0.8.3
arrow                                 1.4.0
arviz                                 0.22.0
astropy                               7.2.2
astropy-iers-data                     0.2026.7.13.0.54.2
astunparse                            1.6.3
atpublic                              5.1
attrs                                 26.1.0
audioread                             3.1.0
Authlib                               1.7.2
autograd                              1.9.1
babel                                 2.18.0
backcall                              0.2.0
beartype                              0.22.9
beautifulsoup4                        4.13.5
betterproto                           2.0.0b6
bigframes                             2.42.0
bigquery-magics                       0.14.0
bleach                                6.4.0
blinker                               1.9.0
blis                                  1.3.3
blobfile                              3.2.0
blosc2                                4.8.0
bokeh                                 3.8.2
Bottleneck                            1.4.2
bqplot                                0.12.47
branca                                0.8.2
brotli                                1.2.0
CacheControl                          0.14.4
cachetools                            6.2.6
catalogue                             2.0.10
certifi                               2026.6.17
cffi                                  2.1.0
chardet                               5.2.0
charset-normalizer                    3.4.9
clarabel                              0.11.1
click                                 8.4.2
cligj                                 0.7.2
cloudpathlib                          0.24.0
cloudpickle                           3.1.2
cmake                                 3.31.10
cmdstanpy                             1.3.0
colorcet                              3.2.1
colorlover                            0.3.0
community                             1.0.0b1
confection                            1.3.3
cons                                  0.4.7
contourpy                             1.3.3
cramjam                               2.11.0
cryptography                          49.0.0
cufflinks                             0.17.3
curl_cffi                             0.15.0
cvxopt                                1.3.2
cvxpy                                 1.6.7
cycler                                0.12.1
cyipopt                               1.5.0
cymem                                 2.0.13
Cython                                3.0.12
dask                                  2026.7.0
dataproc-spark-connect                1.1.0
datasets                              4.0.0
db-dtypes                             1.7.1
dbus-python                           1.2.18
ddgs                                  9.14.4
debugpy                               1.8.15
decorator                             4.4.2
defusedxml                            0.7.1
deprecation                           2.1.0
diffusers                             0.39.0
dill                                  0.3.8
distro                                1.9.0
dlib                                  19.24.6
dm-tree                               0.1.10
docstring_parser                      0.18.0
docutils                              0.21.2
dopamine_rl                           4.1.2
duckdb                                1.3.2
earthengine-api                       1.7.35
easydict                              1.13
editdistance                          0.8.1
eerepr                                0.1.2
einops                                0.8.2
en_core_web_sm                        3.8.0
entrypoints                           0.4
esda                                  2.9.0
et_xmlfile                            2.0.0
etils                                 1.14.0
etuples                               0.3.10
fake-useragent                        2.2.0
Farama-Notifications                  0.0.6
fastai                                2.8.7
fastapi                               0.139.0
fastcore                              2.0.5
fastdownload                          0.0.7
fastjsonschema                        2.21.2
fastlite                              0.2.4
fastprogress                          1.1.6
fasttransform                         0.0.2
filelock                              3.29.7
firebase-admin                        6.9.0
Flask                                 3.1.3
flatbuffers                           25.12.19
flax                                  0.11.2
folium                                0.20.0
fonttools                             4.63.0
fqdn                                  1.5.1
frozendict                            2.4.7
frozenlist                            1.8.0
fsspec                                2025.3.0
future                                1.0.0
gast                                  0.7.0
gcsfs                                 2025.3.0
GDAL                                  3.8.4
gdown                                 5.2.2
geemap                                0.38.3
geocoder                              1.38.1
geographiclib                         2.1
geopandas                             1.1.4
geopy                                 2.4.1
giddy                                 2.3.6
gin-config                            0.5.0
gitdb                                 4.0.12
GitPython                             3.1.51
glob2                                 0.7
google                                3.0.0
google-adk                            2.4.0
google-ai-generativelanguage          0.6.15
google-api-core                       2.30.3
google-api-python-client              2.198.0
google-auth                           2.49.0
google-auth-httplib2                  0.4.0
google-auth-oauthlib                  1.4.0
google-cloud-bigquery                 3.42.2
google-cloud-bigquery-connection      1.22.0
google-cloud-bigquery-storage         2.39.0
google-cloud-core                     2.6.0
google-cloud-dataproc                 5.28.0
google-cloud-datastore                2.25.0
google-cloud-firestore                2.27.0
google-cloud-functions                1.24.0
google-cloud-language                 2.21.0
google-cloud-monitoring               2.31.0
google-cloud-resource-manager         1.18.0
google-cloud-spanner                  3.68.0
google-cloud-storage                  3.13.0
google-cloud-translate                3.27.0
google-colab                          1.0.0
google-crc32c                         1.8.0
google-genai                          2.11.0
google-generativeai                   0.8.6
google-pasta                          0.2.0
google-resumable-media                2.10.0
googleapis-common-protos              1.75.0
googledrivedownloader                 1.1.0
gradio                                6.20.0
gradio_client                         2.5.0
grain                                 0.2.18
graphviz                              0.21
greenlet                              3.5.3
groovy                                0.1.2
grpc-google-iam-v1                    0.14.4
grpc-interceptor                      0.15.4
grpcio                                1.82.1
grpcio-status                         1.71.2
grpclib                               0.4.9
gspread                               6.2.1
gspread-dataframe                     4.0.0
gym                                   0.25.2
gym-notices                           0.1.0
gymnasium                             1.3.0
h11                                   0.16.0
h2                                    4.3.0
h5netcdf                              1.8.1
h5py                                  3.16.0
hdbscan                               0.8.44
hf-gradio                             0.4.1
hf-xet                                1.5.1
highspy                               1.15.1
holidays                              0.100
holoviews                             1.23.1
hpack                                 4.2.0
html5lib                              1.1
httpcore                              1.0.9
httpcore2                             2.5.0
httpimport                            1.4.1
httplib2                              0.32.0
httptools                             0.8.0
httpx                                 0.28.1
httpx2                                2.5.0
huggingface_hub                       1.23.0
humanize                              4.16.0
hyperframe                            6.1.0
hyperopt                              0.2.7
ibis-framework                        9.5.0
idna                                  3.18
ImageIO                               2.37.3
imageio-ffmpeg                        0.6.0
imagesize                             2.0.0
imbalanced-learn                      0.14.2
immutabledict                         4.3.1
importlib_metadata                    9.0.0
importlib_resources                   7.1.0
imutils                               0.5.4
inequality                            1.1.2
inflect                               7.5.0
iniconfig                             2.3.0
intel-cmplr-lib-ur                    2025.3.3
intel-openmp                          2025.3.3
ipyevents                             2.0.4
ipyfilechooser                        0.6.0
ipykernel                             6.17.1
ipyleaflet                            0.20.0
ipyparallel                           8.8.0
ipython                               7.34.0
ipython-genutils                      0.2.0
ipython-sql                           0.5.0
ipywidgets                            7.7.1
isoduration                           20.11.0
itsdangerous                          2.2.0
jaraco.classes                        3.4.0
jaraco.context                        6.1.2
jaraco.functools                      4.5.0
jax                                   0.7.2
jaxlib                                0.7.2
jeepney                               0.9.0
jieba                                 0.42.1
Jinja2                                3.1.6
jiter                                 0.16.0
joblib                                1.5.3
joserfc                               1.7.3
jsonpatch                             1.33
jsonpickle                            4.1.2
jsonpointer                           3.1.1
jsonschema                            4.26.0
jsonschema-specifications             2025.9.1
jupyter_client                        7.4.9
jupyter-console                       6.6.3
jupyter_core                          5.9.1
jupyter-events                        0.12.1
jupyter_kernel_gateway                2.5.2
jupyter-leaflet                       0.20.0
jupyter_server                        2.20.0
jupyter_server_terminals              0.5.4
jupyterlab_pygments                   0.3.0
jupyterlab_widgets                    3.0.16
jupytext                              1.19.4
kaggle                                2.0.2
kagglehub                             1.0.2
kagglesdk                             0.1.23
keras                                 3.13.2
keras-hub                             0.26.0
keras-nlp                             0.26.0
keyring                               25.7.0
keyrings.google-artifactregistry-auth 1.1.2
kiwisolver                            1.5.0
langchain                             1.3.13
langchain-core                        1.4.9
langchain-protocol                    0.0.18
langgraph                             1.2.9
langgraph-checkpoint                  4.1.1
langgraph-prebuilt                    1.1.0
langgraph-sdk                         0.4.2
langsmith                             0.10.2
lark                                  1.3.1
launchpadlib                          1.10.16
lazr.restfulclient                    0.14.4
lazr.uri                              1.0.6
lazy-loader                           0.5
libclang                              18.1.1
libpysal                              4.14.1
librosa                               0.11.0
lightgbm                              4.6.0
linkify-it-py                         2.1.0
llvmlite                              0.43.0
locket                                1.0.0
logical-unification                   0.4.7
lxml                                  6.1.1
Mako                                  1.1.3
mapclassify                           2.10.0
Markdown                              3.10.2
markdown-it-py                        4.2.0
markdownify                           1.2.3
MarkupSafe                            3.0.3
matplotlib                            3.10.0
matplotlib-inline                     0.2.2
matplotlib-venn                       1.1.2
mdit-py-plugins                       0.6.1
mdurl                                 0.1.2
mgwr                                  2.2.1
miniKanren                            1.0.5
missingno                             0.5.2
mistune                               3.3.3
mizani                                0.13.5
mkl                                   2025.3.1
ml_dtypes                             0.5.4
mlxtend                               0.23.4
mmh3                                  5.2.1
momepy                                0.11.0
more-itertools                        10.8.0
moviepy                               1.0.3
mpmath                                1.3.0
msgpack                               1.2.1
multidict                             6.7.1
multipledispatch                      1.0.0
multiprocess                          0.70.16
multitasking                          0.0.13
murmurhash                            1.0.15
music21                               9.9.2
namex                                 0.1.0
narwhals                              2.24.0
natsort                               8.4.0
nbclassic                             1.3.3
nbclient                              0.10.4
nbconvert                             7.17.1
nbformat                              5.10.4
ndindex                               1.10.1
nest-asyncio                          1.6.0
networkx                              3.6.1
nh3                                   0.3.6
nibabel                               5.4.2
nltk                                  3.9.1
notebook                              6.5.7
notebook_shim                         0.2.4
numba                                 0.60.0
numexpr                               2.14.1
numpy                                 2.0.2
nvidia-nccl-cu12                      2.30.7
oauth2client                          4.1.3
oauthlib                              3.3.1
omegaconf                             2.3.1
onemkl-license                        2025.3.1
openai                                2.45.0
opencv-contrib-python                 4.13.0.92
opencv-python                         5.0.0.93
opencv-python-headless                5.0.0.93
openpyxl                              3.1.5
opentelemetry-api                     1.42.1
opentelemetry-resourcedetector-gcp    1.12.0a0
opentelemetry-sdk                     1.42.1
opentelemetry-semantic-conventions    0.63b1
opt_einsum                            3.4.0
optax                                 0.2.8
optree                                0.19.1
orbax-checkpoint                      0.12.1
orjson                                3.11.9
ormsgpack                             1.12.2
osqp                                  1.1.3
packaging                             26.2
pandas                                2.2.2
pandas-datareader                     0.11.1
pandas-gbq                            0.30.0
pandas-stubs                          2.2.2.240909
pandocfilters                         1.5.1
panel                                 1.9.3
panel-material-ui                     0.14.0
param                                 2.4.1
parso                                 0.8.7
parsy                                 2.2
partd                                 1.4.2
patsy                                 1.0.2
peewee                                4.2.2
peft                                  0.19.1
pexpect                               4.9.0
pickleshare                           0.7.5
pillow                                11.3.0
pip                                   24.1.2
platformdirs                          4.10.0
plotly                                5.24.1
plotnine                              0.14.5
pluggy                                1.6.0
plum-dispatch                         2.9.0
pointpats                             2.5.5
polars                                1.35.2
polars-runtime-32                     1.35.2
pooch                                 1.9.0
portpicker                            1.5.2
preshed                               3.0.13
prettytable                           3.18.0
primp                                 1.3.1
proglog                               0.1.12
progressbar2                          4.5.0
prometheus_client                     0.25.0
promise                               2.3
prompt_toolkit                        3.0.52
propcache                             0.5.2
prophet                               1.3.0
proto-plus                            1.28.1
protobuf                              5.29.6
psutil                                5.9.5
psycopg2                              2.9.12
psygnal                               0.15.1
ptyprocess                            0.7.0
PuLP                                  3.3.2
py-cpuinfo                            9.0.0
py4j                                  0.10.9.9
pyarrow                               18.1.0
pyasn1                                0.6.4
pyasn1_modules                        0.4.2
pycairo                               1.29.0
pycocotools                           2.0.11
pycparser                             3.0
pycryptodomex                         3.23.0
pydantic                              2.13.4
pydantic_core                         2.46.4
pydata-google-auth                    1.9.1
pydot                                 4.0.1
pydotplus                             2.0.2
PyDrive2                              1.21.1
pydub                                 0.25.1
pyerfa                                2.0.1.5
pygame                                2.6.1
pygit2                                1.19.3
Pygments                              2.20.0
PyGObject                             3.48.2
pyiceberg                             0.11.1
PyJWT                                 2.13.0
pymc                                  5.28.5
pynndescent                           0.6.0
pyogrio                               0.13.0
pyomo                                 6.10.1
PyOpenGL                              3.1.10
pyOpenSSL                             26.3.0
pyparsing                             3.3.2
pyperclip                             1.11.0
pyproj                                3.7.2
pyroaring                             1.1.0
pysal                                 25.7
pyshp                                 3.1.4
PySocks                               1.7.1
pyspark                               4.0.3
pytensor                              2.38.3
pytest                                8.4.2
python-apt                            0.0.0
python-box                            7.4.1
python-dateutil                       2.9.0.post0
python-dotenv                         1.2.2
python-fasthtml                       0.14.6
python-json-logger                    4.1.0
python-louvain                        0.16
python-multipart                      0.0.32
python-slugify                        8.0.4
python-snappy                         0.7.3
python-utils                          4.0.0
pytz                                  2025.2
pyviz_comms                           3.0.6
PyWavelets                            1.9.0
PyYAML                                6.0.3
pyzmq                                 26.2.1
quantecon                             0.11.3
rasterio                              1.5.0
rasterstats                           0.21.0
ratelim                               0.1.6
referencing                           0.37.0
regex                                 2025.11.3
requests                              2.32.4
requests-oauthlib                     2.0.0
requests-toolbelt                     1.0.0
requirements-parser                   0.9.0
rfc3339-validator                     0.1.4
rfc3986-validator                     0.1.1
rfc3987-syntax                        1.1.0
rich                                  13.9.4
roman-numerals                        4.1.0
roman-numerals-py                     4.1.0
rpds-py                               2026.6.3
rpy2                                  3.5.17
rsa                                   4.9.1
rtree                                 1.4.1
safehttpx                             0.1.7
safetensors                           0.8.0
scikit-image                          0.25.2
scikit-learn                          1.6.1
scipy                                 1.16.3
scooby                                0.11.2
scs                                   3.2.11
seaborn                               0.13.2
SecretStorage                         3.5.0
segregation                           2.5.4
semantic-version                      2.10.0
Send2Trash                            2.1.0
sentence-transformers                 5.6.0
sentencepiece                         0.2.2
sentry-sdk                            2.65.0
setuptools                            75.2.0
shap                                  0.52.0
shapely                               2.1.2
shellingham                           1.5.4
simple-parsing                        0.1.8
simplejson                            4.1.1
simsimd                               6.5.16
six                                   1.17.0
sklearn-compat                        0.1.6
sklearn-pandas                        2.2.0
slicer                                0.0.8
smart_open                            8.0.0
smmap                                 5.0.3
smolagents                            1.26.0
sniffio                               1.3.1
snowballstemmer                       3.1.1
socksio                               1.0.0
soundfile                             0.14.0
soupsieve                             2.8.4
soxr                                  1.1.0
spacy                                 3.8.14
spacy-legacy                          3.0.12
spacy-loggers                         1.0.5
spaghetti                             1.7.6
spanner-graph-notebook                1.1.10
spglm                                 1.1.0
Sphinx                                8.2.3
sphinxcontrib-applehelp               2.0.0
sphinxcontrib-devhelp                 2.0.0
sphinxcontrib-htmlhelp                2.1.0
sphinxcontrib-jsmath                  1.0.1
sphinxcontrib-qthelp                  2.0.0
sphinxcontrib-serializinghtml         2.0.0
spint                                 1.1.0
splot                                 1.1.7
spopt                                 0.7.0
spreg                                 1.9.0
SQLAlchemy                            2.0.51
sqlglot                               25.20.2
sqlparse                              0.5.5
srsly                                 2.5.3
stanio                                0.5.1
starlette                             1.3.1
statsmodels                           0.14.6
strictyaml                            1.7.3
stringzilla                           4.6.2
stumpy                                1.13.0
sympy                                 1.14.0
tables                                3.10.2
tabulate                              0.9.0
tbb                                   2022.3.1
tcmlib                                1.5.0
tenacity                              9.1.4
tensorboard                           2.20.0
tensorboard-data-server               0.7.2
tensorflow                            2.20.0
tensorflow-datasets                   4.9.10
tensorflow-hub                        0.16.1
tensorflow-metadata                   1.21.0
tensorflow-probability                0.25.0
tensorflow-text                       2.20.1
tensorstore                           0.1.84
termcolor                             3.3.0
terminado                             0.18.1
text-unidecode                        1.3
textblob                              0.19.0
tf_keras                              2.20.0
tf-slim                               1.1.0
thinc                                 8.3.13
threadpoolctl                         3.6.0
tifffile                              2026.4.11
tiktoken                              0.13.0
timm                                  1.0.28
tinycss2                              1.5.1
tobler                                0.14.0
tokenizers                            0.22.2
toml                                  0.10.2
tomlkit                               0.14.0
toolz                                 0.12.1
torch                                 2.11.0+cpu
torchao                               0.10.0
torchaudio                            2.11.0+cpu
torchcodec                            0.11.0+cpu
torchdata                             0.11.0
torchsummary                          1.5.1
torchtune                             0.6.1
torchvision                           0.26.0+cpu
tornado                               6.5.7
tqdm                                  4.67.3
traitlets                             5.7.1
traittypes                            0.2.3
transformers                          5.13.1
treescope                             0.1.10
truststore                            0.10.4
tsfresh                               0.21.2
tweepy                                4.17.0
typeguard                             4.5.2
typer                                 0.26.8
types-pytz                            2026.2.0.20260518
types-setuptools                      82.0.0.20260518
typing_extensions                     4.16.0
typing-inspection                     0.4.2
tzdata                                2026.3
tzlocal                               5.4.4
uc-micro-py                           2.0.0
umap-learn                            0.5.12
umf                                   1.0.3
uri-template                          1.3.0
uritemplate                           4.2.0
urllib3                               2.5.0
uuid_utils                            0.17.0
uvicorn                               0.51.0
uvloop                                0.22.1
vega-datasets                         0.9.0
wadllib                               1.3.6
wandb                                 0.28.0
wasabi                                1.1.3
watchdog                              6.0.0
watchfiles                            1.2.0
wcwidth                               0.8.2
weasel                                1.0.0
webcolors                             25.10.0
webencodings                          0.5.1
websocket-client                      1.9.0
websockets                            15.0.1
Werkzeug                              3.1.8
wheel                                 0.47.0
widgetsnbextension                    3.6.10
wordcloud                             1.9.6
wrapt                                 2.2.2
xarray                                2025.12.0
xarray-einstats                       0.10.0
xgboost                               3.3.0
xlrd                                  2.0.2
xxhash                                3.8.1
xyzservices                           2026.3.0
yarl                                  1.24.2
ydf                                   0.15.0
ydf_tf                                2.20.0
yellowbrick                           1.5
yfinance                              0.2.66
zipp                                  4.1.0
zstandard                             0.25.0
/content# ^C
/content#

# %% [markdown]
# https://huggingface.co/smolagents/SmolVLM2-2.2B-Instruct-Agentic-GUI

# %%
# !pip install num2words
# Out:
# Collecting num2words
#   Downloading num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Collecting docopt>=0.6.2 (from num2words)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Downloading num2words-0.5.14-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 11.4 MB/s eta 0:00:00
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=fadd891f03c586183453ae21a6202637a897a33f3e376a7962c875d3c18cbfa9
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built docopt
# Installing collected packages: docopt, num2words
# Successfully installed docopt-0.6.2 num2words-0.5.14

# %% [markdown]
# شغال وانا الل اوقفته

# %%
from smolagents import CodeAgent, TransformersModel, DuckDuckGoSearchTool

# لاحظ هنا أننا نستخدم TransformersModel مباشرة لأنه الموديل الرسمي
model = TransformersModel(model_id="smolagents/SmolVLM2-2.2B-Instruct-Agentic-GUI")

agent = CodeAgent(
    tools=[DuckDuckGoSearchTool()],
    model=model,
)

# الموديل الآن يمكنه "رؤية" الصور لو أردت!
result = agent.run("ما هو سعر سهم إنفيديا اليوم؟")
print(result)
# Out:
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# [transformers] Model config: pad_token_id must be `None` or an integer within the vocabulary (between 0 and 31999), got 128002. This may result in unexpected behavior.
# Loading weights:   0%|          | 0/657 [00:00<?, ?it/s]
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ ما هو سعر سهم إنفيديا اليوم؟                                                                                    │
# │                                                                                                                 │
# ╰─ TransformersModel - smolagents/SmolVLM2-2.2B-Instruct-Agentic-GUI ─────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# [transformers] Kwargs passed to `processor.__call__` have to be in `processor_kwargs` dict, not in `**kwargs`
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   The answer is '5'
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Code parsing failed on line 1 due to: SyntaxError: invalid syntax (<unknown>, line 1)
# The answer is '5'
#      ^
# [Step 1: Duration 1245.05 seconds| Input tokens: 2,375 | Output tokens: 17]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# [transformers] Kwargs passed to `processor.__call__` have to be in `processor_kwargs` dict, not in `**kwargs`
# [Step 2: Duration 1198.05 seconds]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_17396/445737825.py in <cell line: 0>()
#      10
#      11 # الموديل الآن يمكنه "رؤية" الصور لو أردت!
# ---> 12 result = agent.run("ما هو سعر سهم إنفيديا اليوم؟")
#      13 print(result)
#
# /usr/local/lib/python3.12/dist-packages/smolagents/agents.py in run(self, task, stream, reset, images, additional_args, max_steps, return_full_result)
#     497
#     498         run_start_time = time.time()
# --> 499         steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     500
#     501         # Outputs are returned only at the end. We only look at the last step.
#
# /usr/local/lib/python3.12/dist-packages/smolagents/agents.py in _run_stream(self, task, max_steps, images)
#     576             self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
#     577             try:
# --> 578                 for output in self._step_stream(action_step):
#     579                     # Yield all
#     580                     yield output
#
# /usr/local/lib/python3.12/dist-packages/smolagents/agents.py in _step_stream(self, memory_step)
#    1675                 output_text = chat_message.content
#    1676             else:
# -> 1677                 chat_message: ChatMessage = self.model.generate(
#    1678                     input_messages,
#    1679                     stop_sequences=stop_sequences,
#
# /usr/local/lib/python3.12/dist-packages/smolagents/models.py in generate(self, messages, stop_sequences, response_format, tools_to_call_from, **kwargs)
#    1067         )
#    1068         count_prompt_tokens = generation_kwargs["inputs"].shape[1]  # type: ignore
# -> 1069         out = self.model.generate(
#    1070             **generation_kwargs,
#    1071         )
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     122         # pyrefly: ignore [bad-context-manager]
#     123         with ctx_factory():
# --> 124             return func(*args, **kwargs)
#     125
#     126     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, custom_generate, **kwargs)
#    2643
#    2644         # 9. Call generation mode
# -> 2645         result = decoding_method(
#    2646             self,
#    2647             input_ids,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2843
#    2844         prefill_consumed = False
# -> 2845         outputs = self._prefill(
#    2846             input_ids,
#    2847             generation_config,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _prefill(self, input_ids, generation_config, model_kwargs, is_first_iteration)
#    3894                 **model_kwargs,
#    3895             )
# -> 3896             return self(**model_inputs, return_dict=True)
#    3897
#    3898         # Chunked prefill (for very large contexts)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     909         if return_dict_passed is not None:
#     910             return_dict = return_dict_passed
# --> 911         output = func(self, *args, **kwargs)
#     912         if not return_dict and not isinstance(output, tuple):
#     913             output = output.to_tuple()
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/smolvlm/modeling_smolvlm.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, pixel_values, pixel_attention_mask, image_hidden_states, labels, use_cache, logits_to_keep, **kwargs)
#     782         ```"""
#     783         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 784         outputs = self.model(
#     785             input_ids=input_ids,
#     786             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#    1038                     output = func(self, *args, **kwargs)
#    1039             else:
# -> 1040                 output = func(self, *args, **kwargs)
#    1041         # Restore original config value
#    1042         finally:
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     909         if return_dict_passed is not None:
#     910             return_dict = return_dict_passed
# --> 911         output = func(self, *args, **kwargs)
#     912         if not return_dict and not isinstance(output, tuple):
#     913             output = output.to_tuple()
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/smolvlm/modeling_smolvlm.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, pixel_values, pixel_attention_mask, image_hidden_states, use_cache, **kwargs)
#     624             )
#     625
# --> 626         outputs = self.text_model(
#     627             inputs_embeds=inputs_embeds,
#     628             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#    1038                     output = func(self, *args, **kwargs)
#    1039             else:
# -> 1040                 output = func(self, *args, **kwargs)
#    1041         # Restore original config value
#    1042         finally:
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/output_capturing.py in wrapper(self, *args, **kwargs)
#     250             # Run the forward
#     251             try:
# --> 252                 outputs = func(self, *args, **kwargs)
#     253             # Reset the states
#     254             finally:
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, **kwargs)
#     409
#     410         for decoder_layer in self.layers[: self.config.num_hidden_layers]:
# --> 411             hidden_states = decoder_layer(
#     412                 hidden_states,
#     413                 attention_mask=causal_mask,
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_layers.py in __call__(self, *args, **kwargs)
#      91
#      92             return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93         return super().__call__(*args, **kwargs)
#      94
#      95
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states, attention_mask, position_ids, past_key_values, use_cache, position_embeddings, **kwargs)
#     328         residual = hidden_states
#     329         hidden_states = self.post_attention_layernorm(hidden_states)
# --> 330         hidden_states = self.mlp(hidden_states)
#     331         hidden_states = residual + hidden_states
#     332         return hidden_states
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, x)
#     181
#     182     def forward(self, x):
# --> 183         down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#     184         return down_proj
#     185
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     132         Runs the forward pass.
#     133         """
# --> 134         return F.linear(input, self.weight, self.bias)
#     135
#     136     def extra_repr(self) -> str:
#
# KeyboardInterrupt:
